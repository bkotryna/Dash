# %% [markdown]
# # Dash practice with recipes from the Allrecipes project
#
# Follow-on work from the tutorial from:\
# https://realpython.com/python-dash<br>
# https://www.justintodata.com/python-interactive-dashboard-with-plotly-dash-tutorial/
#
# Ideas / Plan:
# - [x] Make sugar column into number
# - [x] Plot average review vs amount of sugar
# - [ ] Interactivity: can choose y (avg_rating or no_ratings) and x (sugar content or calories)

# %% [markdown]
# # Part 0: prep data

# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np

# %%
# read in data
data = pd.read_csv("processed_recipe_data.csv")

# %%
data.head(1)
# Out:
#    recipe_id    title date_published  \
# 0      10004  Pavlova     2019-04-04
#
#                                          description  avg_rating  ratings_no  \
# 0  My grandmother's recipe from New Zealand for t...        4.52          25
#
#                                          recipe_cats  5 stars  4 stars  \
# 0  ['Dessert Recipes', 'Specialty Dessert Recipes...       18        4
#
#    3 stars  ...  nutrition.cholesterolContent  nutrition.fatContent  \
# 0        1  ...                           NaN                   NaN
#
#    nutrition.fiberContent  nutrition.proteinContent  \
# 0                     NaN                     1.4 g
#
#    nutrition.saturatedFatContent  nutrition.servingSize  \
# 0                            NaN                    NaN
#
#    nutrition.sodiumContent  nutrition.sugarContent  nutrition.transFatContent  \
# 0                  21.3 mg                  25.2 g                        NaN
#
#   nutrition.unsaturatedFatContent
# 0                             NaN
#
# [1 rows x 35 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3391 entries, 0 to 3390
# Data columns (total 35 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   recipe_id                        3391 non-null   int64
#  1   title                            3391 non-null   object
#  2   date_published                   3391 non-null   object
#  3   description                      3391 non-null   object
#  4   avg_rating                       3391 non-null   float64
#  5   ratings_no                       3391 non-null   int64
#  6   recipe_cats                      3391 non-null   object
#  7   5 stars                          3391 non-null   int64
#  8   4 stars                          3391 non-null   int64
#  9   3 stars                          3391 non-null   int64
#  10  2 stars                          3391 non-null   int64
#  11  1 star                           3391 non-null   int64
#  12  reviews_no                       3391 non-null   int64
#  13  video_present                    3391 non-null   int64
#  14  photo_count                      3391 non-null   int64
#  15  prepTime                         3391 non-null   int64
#  16  cookTime                         3391 non-null   int64
#  17  totalTime                        3391 non-null   int64
#  18  ingredients_no                   3391 non-null   int64
#  19  ingredient_names                 3391 non-null   object
#  20  steps_no                         3391 non-null   int64
#  21  steps_str                        3391 non-null   object
#  22  steps_words_no                   3391 non-null   int64
#  23  nutrition.calories               3391 non-null   object
#  24  nutrition.carbohydrateContent    3385 non-null   object
#  25  nutrition.cholesterolContent     2909 non-null   object
#  26  nutrition.fatContent             3340 non-null   object
#  27  nutrition.fiberContent           3267 non-null   object
#  28  nutrition.proteinContent         3371 non-null   object
#  29  nutrition.saturatedFatContent    3254 non-null   object
#  30  nutrition.servingSize            0 non-null      float64
#  31  nutrition.sodiumContent          3388 non-null   object
#  32  nutrition.sugarContent           3355 non-null   object
#  33  nutrition.transFatContent        0 non-null      float64
#  34  nutrition.unsaturatedFatContent  0 non-null      float64
# dtypes: float64(4), int64(16), object(15)
# memory usage: 927.4+ KB

# %%
# turn relevant numeric columns into numbers
data['nutrition.sugarContent.g'] = data['nutrition.sugarContent'].str.replace(r' g', '').astype(float)
data['nutrition.calories.kcal'] = data['nutrition.calories'].str.replace(r' calories', '').astype(float)

# %%
# check
data[['nutrition.sugarContent', 'nutrition.sugarContent.g']].head(3)
# Out:
#   nutrition.sugarContent  nutrition.sugarContent.g
# 0                 25.2 g                      25.2
# 1                  8.9 g                       8.9
# 2                 15.5 g                      15.5

# %%
# check
data[['nutrition.calories', 'nutrition.calories.kcal']].head(3)
# Out:
#   nutrition.calories  nutrition.calories.kcal
# 0     108.1 calories                    108.1
# 1     195.6 calories                    195.6
# 2       259 calories                    259.0

# %%
# select only the relevant columns
data = data.iloc[:, [0, 1, 2, 4, 5, 36, 35]]

# %%
# inspect
data.shape
# Out:
# (3391, 7)

# %%
# drop rows that have any null values
data.dropna(axis=0, how='any', inplace=True)

# %%
# inspect
data.shape
# Out:
# (3355, 7)

# %% [markdown]
# # Part I: plain Dash

# %% [markdown]
# ### Import libraries

# %%
import dash
from dash import dcc
from dash import html
from jupyter_dash import JupyterDash 
import pandas as pd

# %% [markdown]
# ### Get data

# %%
data["date_published"] = pd.to_datetime(data["date_published"], format="%Y-%m-%d")
data.sort_values("date_published", inplace=True)

# %%
# inspect
data
# Out:
#       recipe_id                                         title date_published  \
# 5         10030        Mom's Excellent Chocolate Chip Cookies     1997-09-07
# 9         10103                                  Pecan Clouds     1997-09-11
# 10        10145                  Melt in your Mouth Cookies I     1997-09-21
# 2         10014                             Hazelnut Biscotti     1997-09-25
# 1         10007                    Evelyn's Cornflake Cookies     1997-09-26
# ...         ...                                           ...            ...
# 3273      48922                Best Marinated Grilled Chicken     2020-07-02
# 3322      49439                    The Best Steamed Asparagus     2020-07-02
# 1818     283771  Schupfnudeln (German Fried Potato Dumplings)     2021-03-25
# 1816     283744              Poffertjes (Dutch Mini Pancakes)     2021-03-25
# 1819     283834    Käsesahnetorte (German Yogurt Mousse Cake)     2021-03-30
#
#       avg_rating  ratings_no  nutrition.calories.kcal  \
# 5       2.214286          28                    357.7
# 9       4.625000          48                     90.2
# 10      3.840000          50                    267.1
# 2       4.428571          14                    259.0
# 1       4.000000           8                    195.6
# ...          ...         ...                      ...
# 3273    4.375000          32                    844.2
# 3322    4.043478          92                     86.4
# 1818    0.000000           0                    286.1
# 1816    0.000000           0                    104.5
# 1819    0.000000           0                    640.3
#
#       nutrition.sugarContent.g
# 5                         25.1
# 9                          7.1
# 10                        13.2
# 2                         15.5
# 1                          8.9
# ...                        ...
# 3273                      12.5
# 3322                       2.2
# 1818                       1.2
# 1816                       3.0
# 1819                      33.6
#
# [3355 rows x 7 columns]

# %% [markdown]
# ### Style

# %%
external_stylesheets = [
    {
        "href": "https://fonts.googleapis.com/css2?"
                "family=Lato:wght@400;700&display=swap",
        "rel": "stylesheet",
    },
]

# %% [markdown]
# ### Start with Dash

# %%
# create a dash object (an instance of dash class)
app = JupyterDash(__name__, external_stylesheets=external_stylesheets)

# %% [markdown]
# ### Title
#
# The text that appears in the title bar of your web browser, in Google’s search results, and in social media cards when you share your site

# %%
app.title = "Recipes: is it sugar or calories?"

# %% [markdown]
# ### Define the layout of the Dash application
#
# Define the layout property of the application - dictates the look of the app.\
# A heading with a description below it and two graph.

# %%
import plotly.express as px

# %%
fig_avg_rating = px.scatter(data,
                            x="nutrition.sugarContent.g",
                            y="avg_rating")

fig_avg_rating.update_traces(marker=dict(symbol='circle',
                                         color='rgba(235, 195, 35, 0.25)',
                                         line=dict(width=0.25)),
                             hovertemplate = '%{y:.1f} stars for %{x:.1f} g sugar<extra></extra>')

fig_avg_rating.update_xaxes(showgrid=True, gridwidth=0.05, gridcolor='#E1E5EA',
                 zeroline=True, zerolinewidth=1, zerolinecolor='Black')
fig_avg_rating.update_yaxes(showgrid=True, gridwidth=0.05, gridcolor='#E1E5EA',
                 zeroline=True, zerolinewidth=1, zerolinecolor='Black')

fig_avg_rating.update_layout(title=dict(text="What's the average rating?",
                                        x=0.05,
                                        xanchor='left'),
                             xaxis=dict(fixedrange=True,
                                        title='Sugar content per serving (in grams)'),
                             yaxis=dict(fixedrange=True,
                                        title='Average rating'),
                             #paper_bgcolor='rgba(0,0,0,0)',
                             plot_bgcolor='rgba(0,0,0,0)')
# Out:
# <div>                            <div id="0ebaf68d-cdef-40bf-aad8-0bc18e714c90" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0ebaf68d-cdef-40bf-aad8-0bc18e714c90")) {                    Plotly.newPlot(                        "0ebaf68d-cdef-40bf-aad8-0bc18e714c90",                        [{"hovertemplate":"%{y:.1f} stars for %{x:.1f} g sugar<extra></extra>","legendgroup":"","marker":{"color":"rgba(235, 195, 35, 0.25)","symbol":"circle","line":{"width":0.25}},"mode":"markers","name":"","showlegend":false,"x":[25.1,7.1,13.2,15.5,8.9,52.6,6.2,12.4,9.5,14.9,7.1,10.4,44.4,12.4,0.0,12.1,7.7,8.4,5.2,17.5,27.4,107.5,37.8,11.8,33.9,11.2,33.2,19.6,9.0,21.1,3.0,5.7,27.1,14.1,22.9,9.7,8.5,4.4,30.3,34.3,24.9,5.7,13.2,18.2,29.6,8.7,10.6,2.5,55.7,86.0,62.7,6.0,38.8,22.6,19.3,30.6,20.4,54.8,13.2,46.4,24.0,34.0,56.2,34.8,19.6,18.9,38.7,1.2,22.7,23.4,20.8,6.2,4.2,41.9,45.0,25.4,15.2,14.4,28.4,18.3,0.1,6.7,0.1,11.2,1.9,4.7,9.2,4.2,4.3,34.2,25.2,54.6,6.3,3.5,13.5,3.7,3.0,36.9,10.8,21.4,22.0,12.9,39.3,46.8,4.8,38.2,0.6,7.7,13.6,7.9,21.9,21.7,8.5,5.1,4.2,4.7,5.5,3.1,2.1,6.4,8.2,6.4,5.8,1.3,2.0,5.0,3.7,0.5,23.7,24.9,3.4,9.6,2.1,57.6,33.3,15.0,1.8,6.1,4.3,6.0,10.7,0.7,18.4,1.6,5.3,16.9,4.1,4.4,4.8,26.7,0.1,5.4,18.9,3.9,16.2,17.3,40.9,23.3,7.4,1.4,25.1,6.1,22.8,1.8,0.6,0.7,24.4,4.3,23.5,15.0,0.9,1.3,16.7,3.5,66.9,25.9,6.4,56.9,0.6,14.1,3.2,1.5,6.3,4.9,8.6,0.3,7.9,31.8,1.3,4.2,4.2,32.9,41.8,33.1,9.9,17.6,34.3,0.9,26.9,6.3,3.1,4.0,0.9,49.6,5.1,7.5,4.9,11.5
5,8.7,16.4,0.4,2.0,1.4,12.1,68.7,3.8,0.4,1.9,3.7,3.9,9.3,29.5,13.4,58.0,2.7,4.0,9.0,0.4,30.9,14.8,29.5,21.6,7.7,19.4,42.8,46.4,3.6,10.2,5.6,1.5,3.1,5.1,29.0,9.2,7.6,55.4,7.8,1.7,3.8,1.4,0.7,3.6,52.1,0.4,3.2,7.8,1.8,2.6,6.5,13.8,2.9,9.2,27.4,2.9,19.9,1.0,1.2,2.0,8.8,0.4,1.7,8.2,1.6,5.5,1.4,6.2,5.9,38.9,1.0,7.9,6.6,5.2,4.4,5.3,13.3,10.7,42.2,2.3,0.3,10.6,13.1,2.1,14.5,20.1,6.2,1.5,9.2,4.9,1.7,0.7,27.5,21.2,5.2,4.3,3.3,2.5,5.1,0.9,19.4,2.0,1.8,1.8,0.6,2.7,3.4,7.4,0.9,7.5,5.4,1.2,13.0,1.5,1.5,4.9,9.9,5.1,5.4,35.8,50.0,11.2,23.5,3.1,2.4,60.1,36.6,5.5,0.1,9.8,2.4,2.1,6.7,31.2,0 ...

# %%
fig_total_ratings = px.scatter(data,
                                  x="nutrition.sugarContent.g",
                                  y="ratings_no")

fig_total_ratings.update_traces(marker=dict(symbol='circle',
                                         color='rgba(30, 165, 235, 0.25)',
                                         line=dict(width=0.25)),
                             hovertemplate = '%{y:.1f} total ratings for %{x:.1f} g sugar<extra></extra>')

fig_total_ratings.update_xaxes(showgrid=True, gridwidth=0.05, gridcolor='#E1E5EA',
                 zeroline=True, zerolinewidth=1, zerolinecolor='Black')
fig_total_ratings.update_yaxes(showgrid=True, gridwidth=0.05, gridcolor='#E1E5EA',
                 zeroline=True, zerolinewidth=1, zerolinecolor='Black')

fig_total_ratings.update_layout(title=dict(text='How many ratings?',
                                        x=0.05,
                                        xanchor='left'),
                             xaxis=dict(fixedrange=True,
                                        title='Sugar content per serving (in grams)'),
                             yaxis=dict(fixedrange=True,
                                        title='Number of ratings'),
                             #paper_bgcolor='rgba(0,0,0,0)',
                             plot_bgcolor='rgba(0,0,0,0)')
# Out:
# <div>                            <div id="fb910a60-8fe6-4127-b1e5-d0c82fb911b3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fb910a60-8fe6-4127-b1e5-d0c82fb911b3")) {                    Plotly.newPlot(                        "fb910a60-8fe6-4127-b1e5-d0c82fb911b3",                        [{"hovertemplate":"%{y:.1f} stars for %{x:.1f} g sugar<extra></extra>","legendgroup":"","marker":{"color":"rgba(30, 165, 235, 0.25)","symbol":"circle","line":{"width":0.25}},"mode":"markers","name":"","showlegend":false,"x":[25.1,7.1,13.2,15.5,8.9,52.6,6.2,12.4,9.5,14.9,7.1,10.4,44.4,12.4,0.0,12.1,7.7,8.4,5.2,17.5,27.4,107.5,37.8,11.8,33.9,11.2,33.2,19.6,9.0,21.1,3.0,5.7,27.1,14.1,22.9,9.7,8.5,4.4,30.3,34.3,24.9,5.7,13.2,18.2,29.6,8.7,10.6,2.5,55.7,86.0,62.7,6.0,38.8,22.6,19.3,30.6,20.4,54.8,13.2,46.4,24.0,34.0,56.2,34.8,19.6,18.9,38.7,1.2,22.7,23.4,20.8,6.2,4
1.0,9.1,2.6,4.0,20.4,2.4,4.7,35.7,43.7,3.2,0.2,1.3,8.4,45.8,1.8,0.5,1.3,9.1,13.2,26.1,9.3,6.6,4.9,74.0,8.7,8.9,0.9,32.3,4.5,30.7,1.8,12.1,6.1,10.4,30.3,29.3,43.4,7.4,7.7,37.6,0.2,7.4,26.9,11.7,1.2,47.9,22.7,8.7,0.6,50.6,37.5,0.7,6.0,0.4,2.4,1.9,32.3,10.1,5.9,10.2,4.4,45.6,5.3,22.3,34.3,0.3,7.9,25.3,6.4,41.0,39.9,10.8,1.6,4.3,47.0,23.9,4.3,16.4,5.3,8.3,9.5,5.6,64.5,2.3,11.4,34.6,48.1,21.8,60.6,5.4,2.9,10.7,0.6,6.2,25.3,29.0,17.1,3.5,7.0,6.0,0.8,0.1,1.4,0.3,50.4,9.5,29.2,20.7,11.5,13.0,69.9,26.4,47.1,10.0,3.4,4.0,7.2,1.5,4.1,2.0,55.9,38.7,1.0,0.2,37.1,2.0,2.8,3.1,9.2,0.6,11.3,0.4,0.6,2.1,17.4,11.5,8.7,16.4,0.4,2.0,1.4,12.1,68.7,3.8,0.4,1.9,3.7,3.9,9.3,29.5,13.4,58.0,2.7,4.0,9.0,0.4,30.9,14.8,29.5,21.6,7.7,19.4,42.8,46.4,3.6,10.2,5.6,1.5,3.1,5.1,29.0,9.2,7.6,55.4,7.8,1.7,3.8,1.4,0.7,3.6,52.1,0.4,3.2,7.8,1.8,2.6,6.5,13.8,2.9,9.2,27.4,2.9,19.9,1.0,1.2,2.0,8.8,0.4,1.7,8.2,1.6,5.5,1.4,6.2,5.9,38.9,1.0,7.9,6.6,5.2,4.4,5.3,13.3,10.7,42.2,2.3,0.3,10.6,13.1,2.1,14.5,20.1,6.2,1.5,9.2,4.9,1.7,0.7,27.5,21.2,5.2,4.3,3.3,2.5,5.1,0.9,19.4,2.0,1.8,1.8,0.6,2.7,3.4,7.4,0.9,7.5,5.4,1.2,13.0,1.5,1.5,4.9,9.9,5.1,5.4,35.8,50.0,11.2,23.5,3.1,2.4,60.1,36.6,5.5,0.1,9.8,2.4,2.1,6.7,31.2,0 ...

# %%
app.layout = html.Div(
    children=[
        
        html.Div(
            children=[
                html.Img(src=r'assets/apple_pie_logo.jpg', alt='image', className="header-emoji", height="125"),
                html.H1(
                    children="Recipe explorations", className="header-title"),
                html.P(
                    children=["Analyse the behavior of recipe ratings", html.Br(),"based on their nutritional values"],
                    className="header-description")],
            className="header"),
        
        html.Div(
            children=[
                html.Div(
                    children=dcc.Graph(
                        id="price-chart",
                        config={"displayModeBar": False},
                        figure=fig_avg_rating),
                    className="card"),
                html.Div(
                    children=dcc.Graph(
                        id="volume-chart",
                        config={"displayModeBar": False},
                        figure=fig_total_ratings),
                    className="card")],
            className="wrapper")])

# %% [markdown]
# ### Run the application
#
# Run Dash application locally using Flask’s built-in server

# %%
# debug=True => hot-reloading => when you make a change to the app, it reloads automatically
# mode=inline => shows output in a cell

#debug=True,
#mode='inline'

if __name__ == "__main__":
    app.run_server(debug=True)
# Out:
# Dash app running on http://127.0.0.1:8050/
